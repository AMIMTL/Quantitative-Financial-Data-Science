# %% [markdown]
# # Coding Exercises (Part 9)

# %% [markdown]
# Now, you will have the opportunity to analyze your own dataset. <br>
# __Follow the instructions__ and insert your code! You are either requested to
# - Complete the Code and __Fill in the gaps__. Gaps are marked with "__---__" and are __placeholders__ for your code fragment
# - Write Code completely __on your own__

# %% [markdown]
# In some exercises, you will find questions that can only be answered, if your code is correct and returns the right output! The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need a hint, check the __Hints Section__ at the end of this Notebook. Exercises and Hints are numerated accordingly.

# %% [markdown]
# If you need some further help or if you want to check your code, you can also watch the __solutions videos__ or check the __solutions notebook__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Pandas: Advanced Topics

# %% [markdown]
# ### Exercise 9: GroupBy Operations

# %%
#run the cell!
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")
pd.options.display.float_format = '{:.2f}'.format
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_8804\3509115474.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
#run the cell!
listings = pd.read_csv("listings_clean.csv")

# %%
#run the cell!
listings.head()
# Out:
#   Symbol Exchange                           Name  Last_Price     Market_Cap  \
# 0      A     NYSE     Agilent Technologies, Inc.       81.68 25934696179.92
# 1     AA     NYSE              Alcoa Corporation       29.15  5407809589.60
# 2   AABA   NASDAQ                    Altaba Inc.       75.39 42781131315.30
# 3    AAC     NYSE             AAC Holdings, Inc.        2.16    53141086.80
# 4    AAL   NASDAQ  American Airlines Group, Inc.       34.02 15276869742.96
#
#    IPO_Year            Sector  \
# 0      1999     Capital Goods
# 1      2016  Basic Industries
# 2      1969        Technology
# 3      2014       Health Care
# 4      1969    Transportation
#
#                                            Industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1                                          Aluminum
# 2                                      EDP Services
# 3                              Medical Specialities
# 4                     Air Freight/Delivery Services

# %%
#run the cell!
listings.tail()
# Out:
#      Symbol Exchange                           Name  Last_Price    Market_Cap  \
# 6847   ZUMZ   NASDAQ                    Zumiez Inc.       26.72  681919062.56
# 6848    ZUO     NYSE                    Zuora, Inc.       19.79 2147266454.00
# 6849   ZYME     NYSE                 Zymeworks Inc.       15.74  504078206.26
# 6850   ZYNE   NASDAQ  Zynerba Pharmaceuticals, Inc.        7.85  165399468.60
# 6851   ZYXI   NASDAQ                    Zynex, Inc.        5.02  161834880.48
#
#       IPO_Year             Sector  \
# 6847      2005  Consumer Services
# 6848      2018         Technology
# 6849      2017        Health Care
# 6850      2015        Health Care
# 6851      1969        Health Care
#
#                                                Industry
# 6847                     Clothing/Shoe/Accessory Stores
# 6848            Computer Software: Prepackaged Software
# 6849                              Major Pharmaceuticals
# 6850                              Major Pharmaceuticals
# 6851  Biotechnology: Electromedical & Electrotherape...

# %%
#run the cell!
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6852 entries, 0 to 6851
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      6852 non-null   object
#  1   Exchange    6852 non-null   object
#  2   Name        6852 non-null   object
#  3   Last_Price  6852 non-null   float64
#  4   Market_Cap  6852 non-null   float64
#  5   IPO_Year    6852 non-null   int64
#  6   Sector      5309 non-null   object
#  7   Industry    5309 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 428.4+ KB

# %% [markdown]
# 83. __Group__ listings by the column __Exchange__ and __calculate__ the __mean__/average __Last_Price__ for each Exchange (mean price for nyse, for nasdaq and for amex)! <br>
# __Fill in the gaps!__ Which Exchange has, on average, the highest prices?

# %%
listings.groupby("Exchange").Last_Price.mean()
# Out:
# Exchange
# AMEX     24.24
# NASDAQ   32.27
# NYSE     43.04
# Name: Last_Price, dtype: float64

# %% [markdown]
# The highest prices are ... on NYSE.

# %% [markdown]
# 84. __Group__ listings by the column __Sector__ and return the __highest/maximum Market_Cap__ that can be found on each Sector! <br> __Fill in the gaps__! What is the __Market Cap__ of the largest company in the Sector __Consumer Durables__ (divide by 1 Mio. to grasp large numbers!)?

# %%
listings.groupby('Sector').agg({'Market_Cap':'max'}).sort_values('Market_Cap', ascending= True)/1000000000
# Out:
#                        Market_Cap
# Sector
# Consumer Durables           41.86
# Transportation             184.99
# Consumer Non-Durables      199.39
# Capital Goods              206.00
# Public Utilities           242.06
# Basic Industries           261.79
# Finance                    342.13
# Energy                     345.39
# Health Care                361.02
# Miscellaneous              482.64
# Consumer Services          907.41
# Technology                 945.98

# %% [markdown]
# The Market Cap is ... 41.86 billion US-Dollar

# %% [markdown]
# 85. __Count__ the __amount of listings__ per IPO_Year (hint: count __Symbols__) and __save__ the new DataFrame in the variable __listings_per_year__! __Fill in the gaps!__ <br>

# %%
listings.head()
# Out:
#   Symbol Exchange                           Name  Last_Price     Market_Cap  \
# 0      A     NYSE     Agilent Technologies, Inc.       81.68 25934696179.92
# 1     AA     NYSE              Alcoa Corporation       29.15  5407809589.60
# 2   AABA   NASDAQ                    Altaba Inc.       75.39 42781131315.30
# 3    AAC     NYSE             AAC Holdings, Inc.        2.16    53141086.80
# 4    AAL   NASDAQ  American Airlines Group, Inc.       34.02 15276869742.96
#
#    IPO_Year            Sector  \
# 0      1999     Capital Goods
# 1      2016  Basic Industries
# 2      1969        Technology
# 3      2014       Health Care
# 4      1969    Transportation
#
#                                            Industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1                                          Aluminum
# 2                                      EDP Services
# 3                              Medical Specialities
# 4                     Air Freight/Delivery Services

# %%
listings_per_year = listings.groupby("IPO_Year")[['Symbol']].count()

# %%
# run the cell!
listings_per_year.sort_values('Symbol', ascending= False)
# Out:
#           Symbol
# IPO_Year
# 1969        3747
# 2018         396
# 2017         307
# 2014         272
# 2015         216
# 2016         195
# 2013         186
# 2012         110
# 2004          95
# 2011          94
# 2019          86
# 2007          84
# 2010          84
# 1993          77
# 2005          68
# 2006          68
# 2002          62
# 1997          62
# 1992          61
# 1999          61
# 1996          55
# 2003          55
# 1994          48
# 2000          43
# 2009          40
# 1998          40
# 1986          36
# 1995          33
# 1991          31
# 1987          28
# 2001          27
# 1988          18
# 1989          17
# 2008          11
# 1983          11
# 1990           9
# 1981           5
# 1985           4
# 1984           3
# 1972           2
# 1982           2
# 1980           2
# 1973           1

# %%
listings_per_year.head()
# Out:
#           Symbol
# IPO_Year
# 1969        3747
# 1972           2
# 1973           1
# 1980           2
# 1981           5

# %% [markdown]
# 86. Create a __lineplot__ for __listings_per_year__ (exclude 1969!)!

# %%
listings_per_year.loc[1972:,].plot(kind = 'line')
plt.show()

# %% [markdown]
# 87. __Group__ listings by the columns __IPO_Year and Sector__ and count the number of listings per group (hint: count Symbol)!<br> __Save__ the resulting DataFrame in the variable __matrix__!

# %%
matrix = listings.groupby(['IPO_Year','Sector']).agg({"Symbol":"count"})

# %%
# run the cell
matrix
# Out:
#                                 Symbol
# IPO_Year Sector
# 1969     Basic Industries          207
#          Capital Goods             236
#          Consumer Durables          89
#          Consumer Non-Durables     143
#          Consumer Services         409
# ...                                ...
# 2019     Health Care                21
#          Miscellaneous               1
#          Public Utilities            2
#          Technology                  1
#          Transportation              1
#
# [372 rows x 1 columns]

# %% [markdown]
# 88. __Rearrange__ matrix by __unstacking Sector__! Use 0 (zero) as fill_value! __Fill in the gaps!__

# %%
matrix = matrix.unstack(fill_value=0)

# %%
# run the cell!
matrix.head()
# Out:
#                    Symbol                                  \
# Sector   Basic Industries Capital Goods Consumer Durables
# IPO_Year
# 1969                  207           236                89
# 1972                    0             0                 0
# 1973                    1             0                 0
# 1980                    0             1                 0
# 1981                    0             1                 0
#
#                                                                              \
# Sector   Consumer Non-Durables Consumer Services Energy Finance Health Care
# IPO_Year
# 1969                       143               409    151     604         348
# 1972                         1                 0      0       0           0
# 1973                         0                 0      0       0           0
# 1980                         0                 0      0       0           0
# 1981                         0                 1      0       1           2
#
#
# Sector   Miscellaneous Public Utilities Technology Transportation
# IPO_Year
# 1969                72              159        214             60
# 1972                 0                0          1              0
# 1973                 0                0          0              0
# 1980                 0                0          1              0
# 1981                 0                0          0              0

# %% [markdown]
# 89. __Select__ all rows/listings with __IPO_Year__ from 1990 (incl.) till today and __save__ the new DataFrame in the variable __matrix1__!

# %%
matrix1 = matrix.loc[1990:]

# %%
# run the cell!
matrix1
# Out:
#                    Symbol                                  \
# Sector   Basic Industries Capital Goods Consumer Durables
# IPO_Year
# 1990                    1             1                 0
# 1991                    0             2                 1
# 1992                    2             4                 0
# 1993                    3             8                 4
# 1994                    5             5                 2
# 1995                    1             4                 1
# 1996                    5             3                 1
# 1997                    1             8                 5
# 1998                    0             2                 1
# 1999                    0             5                 0
# 2000                    0             7                 1
# 2001                    1             0                 0
# 2002                    1             0                 1
# 2003                    1             0                 1
# 2004                    3             4                 1
# 2005                    3             2                 1
# 2006                    2             8                 2
# 2007                    1             3                 0
# 2008                    2             1                 0
# 2009                    1             0                 1
# 2010                    4             7                 1
# 2011                    5             5                 0
# 2012                    4             6                 1
# 2013                    5            11                 3
# 2014                   11            11                 2
# 2015                   11            10                 4
# 2016                   11             5                 1
# 2017                   11             8                 8
# 2018                    9            12                 3
# 2019                    1             0                 0
#
#                                                                              \
# Sector   Consumer Non-Durables Consumer Services Energy Finance Health Care
# IPO_Year
# 1990                         0                 0      1       0           1
# 1991                         1                 6      0       4           5
# 1992                         1                 9      1       4           8
# 1993                         6                18      2       2           1
# 1994                         1                11      1       2           3
# 1995                         3                 7      2       2           2
# 1996                         7                 8      1       3           6
# 1997                         3                 9      2       4           7
# 1998                         2                 2      1       4           4
# 1999                         2                 7      3       5           2
# 2000                         1                 3      1       2          14
# 2001                         2                 1      2       3           4
# 2002                         0                 9      3       3           0
# 2003                         1                 6      1       9           1
# 2004                         2                14      2       8          14
# 2005                         2                10      3       8           7
# 2006                         3                10      2       3           9
# 2007                         1                13      6       7           7
# 2008                         0                 3      0       0           1
# 2009                         1                 9      1       3           5
# 2010                         3                10      2      10           5
# 2011                         4                12     14       5           8
# 2012                         3                17     11      11          10
# 2013                         4                44      6      18          38
# 2014                         2                42     13      34          82
# 2015                         5                33      2      22          76
# 2016                        11                16     12      21          44
# 2017                         7                45     30      64          60
# 2018                         8                29     13     139          88
# 2019                         1                 3      1      44          21
#
#
# Sector   Miscellaneous Public Utilities Technology Transportation
# IPO_Year
# 1990                 0                0          2              0
# 1991                 0                0          4              1
# 1992                 2                0          6              1
# 1993                 0                0         10              1
# 1994                 1                4          9              1
# 1995                 0                1         10              0
# 1996                 0                1         18              2
# 1997                 1                3         12              4
# 1998                 3                1          9              0
# 1999                 7                3         17              1
# 2000                 1                0         13              0
# 2001                 2                0          4              0
# 2002                 0                2          5              2
# 2003                 1                1          2              0
# 2004                 2                2          7              1
# 2005                 3                1          3              6
# 2006                 6                1          8              4
# 2007                 5                6         10              2
# 2008                 0                1          2              1
# 2009                 0                0          7              1
# 2010                 3                2         15              3
# 2011                 3                3         15              0
# 2012                 2                3         16              0
# 2013                 2                5         21              5
# 2014                 7               13         32              6
# 2015                 6                8         23              2
# 2016                 7               25         26              2
# 2017                 4                7         30              8
# 2018                 9                8         47              3
# 2019                 1                2          1              1

# %% [markdown]
# Congrats, you created the DataFrame matrix1 that we visualized in Exercise 7 with a Seaborn Heatmap!

# %%
# run and see again!
import seaborn as sns

plt.figure(figsize=(12,8))
sns.set(font_scale=1.0)
sns.heatmap(matrix1, cmap = "viridis", vmax = 25)
plt.show()

# %% [markdown]
# # Well Done!

# %% [markdown]
# -------------------

# %% [markdown]
# # Hints (Spolier!)

# %% [markdown]
# 83. group by the "Exchange" column, calculate the mean()

# %% [markdown]
# 84. listings.---(---).---.max() / 1000000

# %% [markdown]
# 85. "IPO_Year", Symbol, count()

# %% [markdown]
# 86. listings_per_year[1:].---

# %% [markdown]
# 87. matrix = listings.groupby([---, ---]).---.---

# %% [markdown]
# 88. unstack() method, fill_value parameter

# %% [markdown]
# 89. matrix1 = matrix.loc[---]

# %% [markdown]
# # Coding Exercises (Part 7)

# %% [markdown]
# Now, you will have the opportunity to analyze your own dataset. <br>
# __Follow the instructions__ and insert your code! You are either requested to
# - Complete the Code and __Fill in the gaps__. Gaps are marked with "__---__" and are __placeholders__ for your code fragment.
# - Write Code completely __on your own__

# %% [markdown]
# In some exercises, you will find questions that can only be answered, if your code is correct and returns the right output! The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need a hint, check the __Hints Section__ at the end of this Notebook. Exercises and Hints are numerated accordingly.

# %% [markdown]
# If you need some further help or if you want to check your code, you can also watch the __solutions videos__ or check the __solutions notebook__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Data Visualization with Matplotlib and Seaborn

# %% [markdown]
# ### Exercise 7: Plotting Data with Matplotlib and Seaborn

# %%
# run the cell!
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format

import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')

import seaborn as sns

# %config InlineBackened.figure_format = 'svg'

# %%
# run the cell!
listings = pd.read_csv("listings_clean.csv")

# %%
# run the cell!
listings.head()
# Out:
#   Symbol Exchange                           Name  Last_Price     Market_Cap  \
# 0      A     NYSE     Agilent Technologies, Inc.       81.68 25934696179.92
# 1     AA     NYSE              Alcoa Corporation       29.15  5407809589.60
# 2   AABA   NASDAQ                    Altaba Inc.       75.39 42781131315.30
# 3    AAC     NYSE             AAC Holdings, Inc.        2.16    53141086.80
# 4    AAL   NASDAQ  American Airlines Group, Inc.       34.02 15276869742.96
#
#    IPO_Year            Sector  \
# 0      1999     Capital Goods
# 1      2016  Basic Industries
# 2      1969        Technology
# 3      2014       Health Care
# 4      1969    Transportation
#
#                                            Industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1                                          Aluminum
# 2                                      EDP Services
# 3                              Medical Specialities
# 4                     Air Freight/Delivery Services

# %%
listings.info()

# %%
# run the cell -> Sort listings by IPO_Year & Create new RangeIndex
listings = listings.sort_values("IPO_Year", ascending = True).reset_index(drop = True)

# %%
# run the cell
listings.head()
# Out:
#   Symbol Exchange                               Name  Last_Price  \
# 0   ZYXI   NASDAQ                        Zynex, Inc.        5.02
# 1   RGLD   NASDAQ                   Royal Gold, Inc.       93.25
# 2  GNE^A     NYSE                  Genie Energy Ltd.        8.17
# 3   RGCO   NASDAQ                 RGC Resources Inc.       26.10
# 4    GNK     NYSE  Genco Shipping & Trading Limited         8.66
#
#      Market_Cap  IPO_Year            Sector  \
# 0  161834880.48      1969       Health Care
# 1 6109454655.00      1969  Basic Industries
# 2          0.00      1969               NaN
# 3  209399490.90      1969  Public Utilities
# 4  360749161.02      1969    Transportation
#
#                                             Industry
# 0  Biotechnology: Electromedical & Electrotherape...
# 1                                    Precious Metals
# 2                                                NaN
# 3                               Oil & Gas Production
# 4                              Marine Transportation

# %% [markdown]
# 68. __Import__ matplotlib.pyplot (as plt) and set the __style__ to __"seaborn"__! __Fill in the gaps!__

# %% [markdown]
# 69. __Create__ the graph below (lineplot for all numerical columns, figsize = (15,15))! __Fill in the gaps__!

# %%
listings.select_dtypes(include='number').plot(subplots = True, 
                                              figsize = (15,15),
                                              legend = True,
                                              sharex = True)
plt.legend(fontsize = 15)

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.hist(

# %%
(
    listings.
    loc[listings.Last_Price < 200, 'Last_Price'].
    plot.
    hist(
        figsize = (12,8), 
        x = 'Last_Price',
        xlabel = "Price",
        ylabel = "Frequency",
        title = "Histogram of Stocks with Price < 200",
        fontsize = 13,
        bins = 200
        )
)
plt.legend(loc =0)
plt.show()

# %% [markdown]
# 70. __Create__ the graph below (Histogramm for the __"Last_Price"__ column with 200 bins and figsize of (12, 8)! <br>
# Select listings with __Last_Price < 200__ only! __Fill in the gaps__!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
listings.loc[listings.Last_Price < 200, "Last_Price"].---(figsize = (12,8), --- = 200)
plt.---("Last_Price Frequency Distribution", fontsize = 15)
plt.---("Price", fontsize = 13)
plt.---("Frequency", fontsize = 13)
plt.---

# %% [markdown]
# 71. __Create__ the graph below (Scatterplot with __Last_Price__ on x-axis, __Market_Cap__ on y-axis and __IPO_Year__ as color)! __Fill in the gaps!__ <br><br>
# (Note: by setting xlim and ylim we are limiting our plot to listings with price < 200 and market cap < 10 billion. By setting vmin to 1990, we are scaling the colormap in a way that all listings before 1990 are deep violet.)

# %%
listings.head(0)
# Out:
# Empty DataFrame
# Columns: [Symbol, Exchange, Name, Last_Price, Market_Cap, IPO_Year, Sector, Industry]
# Index: []

# %%
plt.scatter(

# %%
(
    listings.
    plot(
        figsize = (12,8),
        kind = 'scatter',
        x = 'Last_Price',
        y = 'Market_Cap',
        c ='IPO_Year',
        cmap = 'viridis',
        ylim = (0,10000000000),
        xlim = (0,200),
        vmin = 1990
    )
)

plt.title("Price vs. Market_Cap" , fontsize = 15)
plt.xlabel("Price", fontsize = 13)
plt.ylabel("Market_Cap", fontsize = 13)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
listings.plot(kind = "---", 
              x = "Last_Price", 
              y = "Market_Cap", 
              c = "---", 
              colormap = "viridis", 
              figsize = (12,8), 
              xlim = (0, 200), 
              ylim = (0, 10000000000), 
              vmin = 1990)
plt.title("Price vs. Market Cap", fontsize = 15)
plt.xlabel("Price", fontsize = 13)
plt.ylabel("Market_Cap", fontsize = 13)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 listings.plot(kind = "---",
#       2               x = "Last_Price",
#       3               y = "Market_Cap",
#       4               c = "---",
#       5               colormap = "viridis",
#       6               figsize = (12,8),
#       7               xlim = (0, 200),
#       8               ylim = (0, 10000000000),
#       9               vmin = 1990)
#      10 plt.title("Price vs. Market Cap", fontsize = 15)
#      11 plt.xlabel("Price", fontsize = 13)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:908, in PlotAccessor.__call__(self, *args, **kwargs)
#     905     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     907 if kind not in self._all_kinds:
# --> 908     raise ValueError(f"{kind} is not a valid plot kind")
#     910 # The original data structured can be transformed before passed to the
#     911 # backend. For example, for DataFrame is common to set the index as the
#     912 # `x` parameter, and return a Series with the parameter `y` as values.
#     913 data = self._parent.copy()
#
# ValueError: --- is not a valid plot kind

# %%
# run the cell!
listings.head()
# Out:
#   Symbol Exchange                           Name  Last_Price     Market_Cap  \
# 0      A     NYSE     Agilent Technologies, Inc.       81.68 25934696179.92
# 1     AA     NYSE              Alcoa Corporation       29.15  5407809589.60
# 2   AABA   NASDAQ                    Altaba Inc.       75.39 42781131315.30
# 3    AAC     NYSE             AAC Holdings, Inc.        2.16    53141086.80
# 4    AAL   NASDAQ  American Airlines Group, Inc.       34.02 15276869742.96
#
#    IPO_Year            Sector  \
# 0      1999     Capital Goods
# 1      2016  Basic Industries
# 2      1969        Technology
# 3      2014       Health Care
# 4      1969    Transportation
#
#                                            Industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1                                          Aluminum
# 2                                      EDP Services
# 3                              Medical Specialities
# 4                     Air Freight/Delivery Services

# %% [markdown]
# 72. __Import__ Seaborn (as sns)!

# %%
listings.loc[listings.IPO_Year > 2001]
# Out:
#      Symbol Exchange                           Name  Last_Price  \
# 1        AA     NYSE              Alcoa Corporation       29.15
# 3       AAC     NYSE             AAC Holdings, Inc.        2.16
# 8      AAOI   NASDAQ  Applied Optoelectronics, Inc.       12.30
# 12      AAT     NYSE    American Assets Trust, Inc.       46.08
# 13      AAU     AMEX         Almaden Minerals, Ltd.        0.57
# ...     ...      ...                            ...         ...
# 6846    ZTS     NYSE                    Zoetis Inc.      101.33
# 6847   ZUMZ   NASDAQ                    Zumiez Inc.       26.72
# 6848    ZUO     NYSE                    Zuora, Inc.       19.79
# 6849   ZYME     NYSE                 Zymeworks Inc.       15.74
# 6850   ZYNE   NASDAQ  Zynerba Pharmaceuticals, Inc.        7.85
#
#          Market_Cap  IPO_Year             Sector  \
# 1     5407809589.60      2016   Basic Industries
# 3       53141086.80      2014        Health Care
# 8      244556139.90      2013         Technology
# 12    2180759362.56      2011  Consumer Services
# 13      64242863.42      2015   Basic Industries
# ...             ...       ...                ...
# 6846 48552001684.81      2013        Health Care
# 6847   681919062.56      2005  Consumer Services
# 6848  2147266454.00      2018         Technology
# 6849   504078206.26      2017        Health Care
# 6850   165399468.60      2015        Health Care
#
#                                      Industry
# 1                                    Aluminum
# 3                        Medical Specialities
# 8                              Semiconductors
# 12              Real Estate Investment Trusts
# 13                            Precious Metals
# ...                                       ...
# 6846                    Major Pharmaceuticals
# 6847           Clothing/Shoe/Accessory Stores
# 6848  Computer Software: Prepackaged Software
# 6849                    Major Pharmaceuticals
# 6850                    Major Pharmaceuticals
#
# [2429 rows x 8 columns]

# %%
plt.figure(figsize = (12,8))
sns.countplot(listings.loc[listings.IPO_Year > 2001],
              x = 'IPO_Year',
              hue = 'Exchange',
              palette = 'viridis',
             )
sns.set(font_scale=1.1, palette="viridis")
plt.title("IPO_Issued in Exchange Market" , fontsize = 15)
plt.legend()
plt.show()

# %% [markdown]
# 73. __Create__ the following __countplot__! It should show the number/count of listings per Exchange per IPO_Year starting from 2001. __Fill in the gaps!__

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.1, palette="viridis")
sns.---(data = listings.loc[listings.IPO_Year > 2000], --- = "IPO_Year", hue = "---",)
plt.legend(loc= "upper left")
plt.savefig("list_countpl")

# %%
plt.figure(figsize= (12,8))
sns.countplot(listings , 
              x = 'Sector',
              #y = 'Market_Cap',
              hue = 'Exchange',
              palette='viridis',
             )
plt.xticks(rotation = 45, fontsize = 8)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale = 1.1)
sns.barplot(listings , 
            x = 'Sector',
            y = 'Market_Cap',
            hue = 'Exchange',
            palette='Spectral')
plt.title("Stocks Sectors vs. Market_Cap")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# 74. __Create__ the following plot! __Fill in the gaps!__ Do you think that the lower market capitalization of stocks being AMEX listed is __statistically significant__?

# %%
plt.figure(figsize= (8,6))
sns.barplot(listings , 
            x = 'Exchange',
            y = 'Market_Cap',
            dodge= True,
            palette= 'viridis'
           )
plt.title("Exchange Market vs. Market Capitalization", fontsize = 15)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.0)
sns.---(data = ---, x = "Exchange", y = "---", dodge = True)
plt.show()

# %% [markdown]
# It seems to be significant. Listings on the AMEX have - on average - a lower Market Capitalization.

# %% [markdown]
# __Import__ the __matrix1.csv__ file and save the DataFrame in the variable __matrix1__. __Inspect__! <br><br>
# (Note: The matrix1 dataset is an aggregation of the listings dataset and shows the number of listings per IPO_Year per Sector.)

# %%
# run the cell
matrix1 = pd.read_csv("matrix1.csv", index_col = "IPO_Year")

# %%
# run the cell!
matrix1
# Out:
#           Basic Industries  Capital Goods  Consumer Durables  \
# IPO_Year
# 1990                     1              1                  0
# 1991                     0              2                  1
# 1992                     2              4                  0
# 1993                     3              8                  4
# 1994                     5              5                  2
# 1995                     1              4                  1
# 1996                     5              3                  1
# 1997                     1              8                  5
# 1998                     0              2                  1
# 1999                     0              5                  0
# 2000                     0              7                  1
# 2001                     1              0                  0
# 2002                     1              0                  1
# 2003                     1              0                  1
# 2004                     3              4                  1
# 2005                     3              2                  1
# 2006                     2              8                  2
# 2007                     1              3                  0
# 2008                     2              1                  0
# 2009                     1              0                  1
# 2010                     4              7                  1
# 2011                     5              5                  0
# 2012                     4              6                  1
# 2013                     5             11                  3
# 2014                    11             11                  2
# 2015                    11             10                  4
# 2016                    11              5                  1
# 2017                    11              8                  8
# 2018                     9             12                  3
# 2019                     1              0                  0
#
#           Consumer Non-Durables  Consumer Services  Energy  Finance  \
# IPO_Year
# 1990                          0                  0       1        0
# 1991                          1                  6       0        4
# 1992                          1                  9       1        4
# 1993                          6                 18       2        2
# 1994                          1                 11       1        2
# 1995                          3                  7       2        2
# 1996                          7                  8       1        3
# 1997                          3                  9       2        4
# 1998                          2                  2       1        4
# 1999                          2                  7       3        5
# 2000                          1                  3       1        2
# 2001                          2                  1       2        3
# 2002                          0                  9       3        3
# 2003                          1                  6       1        9
# 2004                          2                 14       2        8
# 2005                          2                 10       3        8
# 2006                          3                 10       2        3
# 2007                          1                 13       6        7
# 2008                          0                  3       0        0
# 2009                          1                  9       1        3
# 2010                          3                 10       2       10
# 2011                          4                 12      14        5
# 2012                          3                 17      11       11
# 2013                          4                 44       6       18
# 2014                          2                 42      13       34
# 2015                          5                 33       2       22
# 2016                         11                 16      12       21
# 2017                          7                 45      30       64
# 2018                          8                 29      13      139
# 2019                          1                  3       1       44
#
#           Health Care  Miscellaneous  Public Utilities  Technology  \
# IPO_Year
# 1990                1              0                 0           2
# 1991                5              0                 0           4
# 1992                8              2                 0           6
# 1993                1              0                 0          10
# 1994                3              1                 4           9
# 1995                2              0                 1          10
# 1996                6              0                 1          18
# 1997                7              1                 3          12
# 1998                4              3                 1           9
# 1999                2              7                 3          17
# 2000               14              1                 0          13
# 2001                4              2                 0           4
# 2002                0              0                 2           5
# 2003                1              1                 1           2
# 2004               14              2                 2           7
# 2005                7              3                 1           3
# 2006                9              6                 1           8
# 2007                7              5                 6          10
# 2008                1              0                 1           2
# 2009                5              0                 0           7
# 2010                5              3                 2          15
# 2011                8              3                 3          15
# 2012               10              2                 3          16
# 2013               38              2                 5          21
# 2014               82              7                13          32
# 2015               76              6                 8          23
# 2016               44              7                25          26
# 2017               60              4                 7          30
# 2018               88              9                 8          47
# 2019               21              1                 2           1
#
#           Transportation
# IPO_Year
# 1990                   0
# 1991                   1
# 1992                   1
# 1993                   1
# 1994                   1
# 1995                   0
# 1996                   2
# 1997                   4
# 1998                   0
# 1999                   1
# 2000                   0
# 2001                   0
# 2002                   2
# 2003                   0
# 2004                   1
# 2005                   6
# 2006                   4
# 2007                   2
# 2008                   1
# 2009                   1
# 2010                   3
# 2011                   0
# 2012                   0
# 2013                   5
# 2014                   6
# 2015                   2
# 2016                   2
# 2017                   8
# 2018                   3
# 2019                   1

# %%
# run the cell!
matrix1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 1990 to 2019
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Basic Industries       30 non-null     int64
#  1   Capital Goods          30 non-null     int64
#  2   Consumer Durables      30 non-null     int64
#  3   Consumer Non-Durables  30 non-null     int64
#  4   Consumer Services      30 non-null     int64
#  5   Energy                 30 non-null     int64
#  6   Finance                30 non-null     int64
#  7   Health Care            30 non-null     int64
#  8   Miscellaneous          30 non-null     int64
#  9   Public Utilities       30 non-null     int64
#  10  Technology             30 non-null     int64
#  11  Transportation         30 non-null     int64
# dtypes: int64(12)
# memory usage: 3.0 KB

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale = 1.1)
sns.heatmap(matrix1 , cmap = 'viridis' , vmax = 25)
plt.show()

# %% [markdown]
# 75. __Create__ the follwing  Seaborn __heatmap__ by using the __matrix1__ dataset. __Fill in the gaps!__ <br>
# Which were the __hot Sectors__ in terms of listings in the period __2013-2018__?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.0)
sns.---(---, cmap = "viridis", vmax = 25)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale = 1.1)
sns.heatmap(matrix1.loc[2013:2018,] , cmap = 'viridis' , vmax = 25)
plt.show()

# %% [markdown]
# Hot Sectors were ... Customer Services, Finance, Health Care and Technology.

# %% [markdown]
# # Well Done!

# %% [markdown]
# -----------------------------

# %% [markdown]
# # Hints (Spoiler!)

# %% [markdown]
# 68. plt.style.use()

# %% [markdown]
# 69. plot() method, enable subplots, disable sharex, dont´t forget plt.show()

# %% [markdown]
# 70. hist() method, bins parameter, plt.title(), plt.xlabel(), plt.ylabel(), plt.show()

# %% [markdown]
# 71. "scatter" plot, color of points determined by IPO_Year column

# %% [markdown]
# 72. No further hints on this.

# %% [markdown]
# 73. countplot, pass "IPO_Year" to the x parameter, pass "Exchange" to the hue parameter

# %% [markdown]
# 74. barplot, data is listings, "Market_Cap" is on the y-axis

# %% [markdown]
# 75. heatmap, pass matrix1

# %% [markdown]
# # Coding Exercises (Part 1)

# %% [markdown]
# Now, you will have the opportunity to practice what you have learned. <br>
# __Follow the instructions__ and insert your code!

# %% [markdown]
# The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need some help or if you want to check your code, you can also have a look at the __solutions__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 1: Using Python as a Calculator for TVM Problems

# %% [markdown]
# Use __variables__ where appropriate! __Input__ values and your __final results__ shall be stored in variables.

# %% [markdown]
# 1. You save 2,000 USD for 7 years at an interst rate of 4% p.a.. Calculate the value of your account in 7 Years (__Future Value__)!

# %%
# Store Input values in variables
pv = 2000 # present value
ir = 0.04 # interest rate
n = 7 # number of years
fv = pv * (1+ir)**n # future value
print(f"The future value of the investment after the {n} years is: ${fv:0.2f}")
# Out:
# The future value of the investment after the 7 years is: $2631.86

# %% [markdown]
# 2. You consider to purchase a car in 4 years for 20,000 USD. How many USD do you have to save today (__Present Value__) in your savings account to have 20,000 USD in 4 years? Assume an interst rate of 3.5% p.a.

# %%
# Store Input values in variables
fv = 20000 # future value
ir = 3.5/100 # interest rate
n = 4 # number of years
pv = fv /(1+ir)**n# present value
print(f"The present value to buy a car is: ${pv:0.2f}")
# Out:
# The present value to buy a car is: $17428.84

# %% [markdown]
# 3. Bank B offers you to save 10,000 USD today, getting back 15,000 USD in 10 Years. Calculate the __per annum compound interest rate__. Bank A offers you an interest rate of 4.5% p.a.. Which offer should you accept?

# %% [markdown]
# $$ Present\ Value = \frac{Future\ Value}{(1+Interest\ Rate)^{Number\ of\ Years}} $$
# so we have:
# $$ Interest\ Rate = \sqrt[n]{\frac{Future\ Value}{Present\ Value}} - 1 $$

# %%
pv = 10000
fv = 15000
n = 10

ir = (fv/pv)**(1/n) - 1
print(f"The interest rate is: {ir*100:0.2f}%")
# Out:
# The interest rate is: 4.14%

# %% [markdown]
# 4. One year ago you invested 976 USD in the ABC stock. Recently you received a 40 USD Dividend Payment and the current value of your ABC stock investment is 1,053 USD. Calculate the __Price Return__!

# %%
pv = 976
d = 40 # dividend
p_current = 1053 # current price

ret = (p_current - pv)/pv
print(f"The price return on the stock is: {ret *100:0.2f}%")
# Out:
# The return on the stock is: 7.89%

# %% [markdown]
# 5. Calculate __Dividend Yield__ and __Total Return__ for your ABC stock investment!

# %%
total_ret = (d + p_current - pv)/pv
print(f"The total return on the stock is: {total_ret *100:0.2f}%")
# Out:
# The total return on the stock is: 11.99%

# %%
div_yield = d/pv
print(f"The dividend yield on the stock is: {div_yield *100:0.2f}%")
# Out:
# The dividend yield on the stock is: 4.10%

# %% [markdown]
# 6. Print Price Return, Dividend Yield and Total Return in one single line, __separated by commas__!

# %%
print(ret , total_ret , div_yield , sep = ",")
# Out:
# 0.07889344262295082,0.11987704918032786,0.040983606557377046

# %% [markdown]
# # Well Done!

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------

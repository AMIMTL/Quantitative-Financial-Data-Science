# %% [markdown]
# # Coding Exercises (Part 1)

# %% [markdown]
# Now, you will have the opportunity to practice what you have learned. <br>
# __Follow the instructions__ and insert your code!

# %% [markdown]
# The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need some help or if you want to check your code, you can also have a look at the __solutions__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 6: How to create great graphs with Matplotlib

# %% [markdown]
# 1. Before you can start, you have to __import__ matplotlib.pyplot!

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')

# %config InlineBackend.figure_format = 'svg'
import numpy as np
import pandas as pd

# %% [markdown]
# You consider an investment with the following cashflows:
#
# - -5,000 USD today (Investment)
# - 1,200 USD in 1 year
# - 1,500 USD in 2 years
# - 2,000 USD in 3 years
# - 2,500 USD in 4 years
# - 3,000 USD in 5 years
# - 3,500 USD in 6 years

# %%
# run the cell!
cf = [-5000, 1200, 1500, 2000, 2500, 3000, 2500]
cf
# Out:
# [-5000, 1200, 1500, 2000, 2500, 3000, 2500]

# %% [markdown]
# 2. Create one __list with cumulative cashflows__ and one __list with timestamps__!

# %%
cum_cf = np.cumsum(cf)
cum_cf
# Out:
# array([-5000, -3800, -2300,  -300,  2200,  5200,  7700])

# %% [markdown]
# 3. Visualize __cumulative cashflows__ in a simple __line plot__! (figure size: (12, 8)) (see result below)

# %%
plt.figure(figsize=(10, 6))
plt.title('Cumulative Cash Flow Over Time')
plt.plot(cum_cf, label='Cumulative Cash Flow')
plt.autoscale(enable=True, axis='both', tight=True)
plt.xlabel('Year')
plt.ylabel("Cummulative Cash Flow ($)")
plt.show()

# %% [markdown]
# 4. Visualize __cumulative cashflows__ in a simple __scatter plot__! (figure size: (12, 8)) (see result below)

# %%
plt.figure(figsize=(10,6))
plt.scatter(x = range(len(cum_cf)) , y = cum_cf ,s = 150 , edgecolors='hotpink', linewidths=3, alpha = 0.8)
plt.title("Scatter plot of Cummulative Cash Flow")
plt.xlabel("Year")
plt.ylabel("Cummulative Cash Flow ($)")
plt.show()

# %% [markdown]
# 5. __Customize__ the plot! (see final result below)

# %%
labels =['t'+str(i) for i in range(len(cum_cf))]
labels
# Out:
# ['t0', 't1', 't2', 't3', 't4', 't5', 't6']

# %%
#complete the code!
plt.figure(figsize = (12, 8))
plt.plot([-5000, -3800, -2300, -300, 2200, 5200, 7700] , 
         marker = "D" , 
         color ="red" , 
         linestyle = "-." , 
         markersize = 10 , 
         label = "Cumulative Cash Flows")
#######################################################
labels =['t'+str(i) for i in range(len(cum_cf))]
plt.xticks(ticks = range(len(cum_cf)), labels=labels)
#######################################################
plt.hlines(y = 0 , xmin = 0 , xmax=6 , label='Break Even')
#######################################################
plt.annotate(text='Break Even Point' , xy = (3.1,0.1), xytext=(2.5,2000) ,arrowprops={'color':'black'} , fontsize = 15)
#######################################################
plt.title("Cummulative Cashflows Project B")
plt.xlabel("Time (in Years)")
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Well Done!

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------
